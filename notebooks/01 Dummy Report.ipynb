# %% [markdown]
# # This is the first section of the dummy report!
#
# Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here. Descriptions and other stuff could go here.

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Some other formatting
#
# A list:
#
# - one
# - two
# - three
#
# A numbered list:
#
# 1. one
# 2. two
# 3. three
#
# A table:
#
# |  | 1 | 2 | 3 | 4 |
# |----------------|--------|---------|---------|---------|
# | __column 1__|  5     |   20    |     15  |   10    |

# %% [markdown]
# # Code output

# %% [markdown]
# ## `print` statement

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## Pandas data frames

# %%
pd.DataFrame(np.random.rand(3, 5))
# Out:
#           0         1         2         3         4
# 0  0.575280  0.596310  0.347316  0.896146  0.416792
# 1  0.297930  0.545612  0.888677  0.861685  0.629338
# 2  0.581035  0.733006  0.274624  0.985813  0.418005

# %% [markdown]
# # Make some plots
#
# Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot. Let's create a plot.

# %%
x = np.linspace(0, 10, 100)
for f in [0.5, 1, 2]:
    plt.plot(x, np.sin(f*x))
    plt.title('plot title');

# %%
x = np.linspace(0, 10, 100)
for f in [0.5, 1, 2]:
    plt.figure()
    plt.plot(x, np.sin(f*x))
    plt.title('plot title');
